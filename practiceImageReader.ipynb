# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheer9023/Revise-Q3/blob/main/practiceImageReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uq google.generativeai

# %%
from google.colab import userdata
key=userdata.get('2.O_exp')

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=key)
model=genai.GenerativeModel("gemini-2.0-flash-exp")

# %%
from IPython.display import Markdown

# %%
from google.colab import files

# Upload files
uploaded = files.upload()

# Display uploaded files
for file_name in uploaded.keys():
    print(f"Uploaded file: {file_name}")
# Out:
#      <input type="file" id="files-0cee443f-d524-45c1-871b-e75836228327" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cee443f-d524-45c1-871b-e75836228327">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import PIL.Image
img=PIL.Image.open(file_name)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1132>

# %%
prompt=input("Enter any prompt : ")
response=model.generate_content([prompt,img])
Markdown(response.text)
# Out:
# Enter any prompt : is image me jo h usko roman urdu me btao
# Zaroori Ittilaa:
#
# Agar aap kay ilm mein koi bacha aisa hai jis kay dil mein sorakh ho aur uskay walidain ilaaj ki istita'at nahi rakhtay to aisay bachay ko AFIC Rawalpindi jahan Dr. Brigadier Amjad sahib free device dalein gay.
#
# Jiski qeemat 7 lakh tak hai. Agar aap kay notes mein aisa bacha hai to uski aanay walay Budh say qabil bazil number par rabita kar kay registration karwa lein. Sadqa jariya kay taur par is pegham ko aam karein. Jazak Allah.
#
# 03035967114
# PA to Dr. Amjid AFIC
